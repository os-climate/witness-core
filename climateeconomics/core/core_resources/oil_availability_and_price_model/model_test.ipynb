# %%
from oil_availability_and_price_prediction_model import dataset, price_model, reserves_model

# %%
input_dict = {'year_start':2020, 'year_end': 2100}

# %%
dt = dataset()
re = reserves_model(dt, input_dict)

# %%
pr = price_model(dt,re, input_dict)

# %%
pr.plot_price_preds()

# %%
re.plot_world_reserves_vs_country_shortage()

# %%
re.world_reserves()
